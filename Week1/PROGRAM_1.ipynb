# %% [markdown]
# <a href="https://colab.research.google.com/github/sudheerreddy07/Pythonlab/blob/main/Week1/PROGRAM_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PYTON PROGRAMING

# %%
print("HELLO WORLD")
# Out:
# HELLO WORLD

# %%
print(2+5)
# Out:
# 7

# %%
a = 5
print (a)
# Out:
# 5

# %%
b = 7
print(a + b)
# Out:
# 12

# %%
a =(input())
# Out:
# 7

# %%
type(a)
# Out:
# str

# %%
type(b)
# Out:
# int

# %%
b =(input())
# Out:
# HELLO WORLD

# %%
print(b)
# Out:
# HELLO WORLD

# %%
b = (input())
# Out:
# 55

# %%
print(a , b)
# Out:
# 7 55

# %%
print(55-7)
# Out:
# 48

# %%
print(7//55)
# Out:
# 0

# %%
print(7/55)
# Out:
# 0.12727272727272726

# %%
print(7*55)
# Out:
# 385

# %% [markdown]
# ARTHEMETIC OPERATORS IN PYTON

# %% [markdown]
# 1.Addition          +
# 2.Subtraction       -
# 3.Multiplication    *
# 4.Normal division   /(a/b gives float value)
# 5.floor division    /(a/b gives decimal value)

# %%
a = int(input())
b = int(input())
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
# Out:
# 3
# 5
# 8
# -2
# 15
# 0.6
# 0
